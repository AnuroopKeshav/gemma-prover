# %% [markdown]
# # Setup and imports

# %%
# %cd ..
from utils.setup import setup
from utils.model_analysis import look_at
# Out:
# /home/sam/Projects/gemma-prover/src

# %%
setup()
# Out:
# Setup Complete

# %% [markdown]
# # Model Inspection

# %%
look_at("google/diffusiongemma-26B-A4B-it")
# Out:
# ============================================================================================================================
# Model      : google/diffusiongemma-26B-A4B-it
# Type       : diffusion_gemma / DiffusionGemmaForBlockDiffusion
# Attn impl  : default (forced eager for inspection)
# Activation : gelu_pytorch_tanh
# ============================================================================================================================
# Layer (type) [dims]                                                                                                   Params
# ----------------------------------------------------------------------------------------------------------------------------
# DiffusionGemmaForBlockDiffusion (DiffusionGemmaForBlockDiffusion)                                                     25.82B
#   model (DiffusionGemmaModel)                                                                                         25.82B
#     encoder (DiffusionGemmaEncoderModel)                                                                              25.81B
#       language_model (DiffusionGemmaEncoderTextModel)                                                                 25.23B
#         embed_tokens (DiffusionGemmaTextScaledWordEmbedding) [262144, 2816, padding_idx=0]                           738.20M
#         layers (ModuleList)                                                                                           24.49B
#           (0-29): 30 x DiffusionGemmaEncoderTextLayer
#           0 (DiffusionGemmaEncoderTextLayer)                                                                         814.09M
#             self_attn (DiffusionGemmaEncoderTextAttention)                                                            34.60M
#             mlp (DiffusionGemmaText4MLP)                                                                              17.84M
#             input_layernorm (DiffusionGemmaRMSNorm) [weight (2816,)]                                                   2.82K
#             post_attention_layernorm (DiffusionGemmaRMSNorm) [weight (2816,)]                                          2.82K
#             pre_feedforward_layernorm (DiffusionGemmaRMSNorm) [weight (2816,)]                                         2.82K
#             post_feedforward_layernorm (DiffusionGemmaRMSNorm) [weight (2816,)]                                        2.82K
#             router (DiffusionGemmaTextRouter) [scale (2816,), per_expert_scale (128,)]                               363.39K
#             experts (DiffusionGemmaTextExperts) [gate_up_proj (128, 1408, 2816), down_proj (128, 2816, 704)]         761.27M
#             post_feedforward_layernorm_1 (DiffusionGemmaRMSNorm) [weight (2816,)]                                      2.82K
#             post_feedforward_layernorm_2 (DiffusionGemmaRMSNorm) [weight (2816,)]                                      2.82K
#             pre_feedforward_layernorm_2 (DiffusionGemmaRMSNorm) [weight (2816,)]                                       2.82K
#         norm (DiffusionGemmaRMSNorm) [weight (2816,)]                                                                  2.82K
#         rotary_emb (DiffusionGemmaTextRotaryEmbedding)                                                                     0
#       vision_tower (Gemma4VisionModel)                                                                               569.55M
#         patch_embedder (Gemma4VisionPatchEmbedder) [position_embedding_table (2, 10240, 1152)]                        24.48M
#           input_proj (Linear) [in_features=768, out_features=1152, bias=False]                                       884.74K
#         encoder (Gemma4VisionEncoder)                                                                                545.07M
#           rotary_emb (Gemma4VisionRotaryEmbedding)                                                                         0
#           layers (ModuleList)                                                                                        545.07M
#             (0-26): 27 x Gemma4VisionEncoderLayer
#             0 (Gemma4VisionEncoderLayer)                                                                              20.19M
#         pooler (Gemma4VisionPooler)                                                                                        0
#       embed_vision (DiffusionGemmaMultimodalEmbedder)                                                                  3.24M
#         embedding_projection (Linear) [in_features=1152, out_features=2816, bias=False]                                3.24M
#         embedding_pre_projection_norm (DiffusionGemmaRMSNorm)                                                              0
#     decoder (DiffusionGemmaDecoderModel)                                                                              25.25B
#       embed_tokens (DiffusionGemmaTextScaledWordEmbedding) [262144, 2816, padding_idx=0]                             738.20M
#       layers (ModuleList)                                                                                             24.49B
#         (0-29): 30 x DiffusionGemmaDecoderTextLayer
#         0 (DiffusionGemmaDecoderTextLayer)                                                                           814.09M
#           self_attn (DiffusionGemmaDecoderTextAttention)                                                              34.60M
#             q_proj (Linear) [in_features=2816, out_features=4096, bias=False]                                         11.53M
#             k_proj (Linear) [in_features=2816, out_features=2048, bias=False]                                          5.77M
#             v_proj (Linear) [in_features=2816, out_features=2048, bias=False]                                          5.77M
#             o_proj (Linear) [in_features=4096, out_features=2816, bias=False]                                         11.53M
#             q_norm (DiffusionGemmaRMSNorm) [weight (256,)]                                                               256
#             k_norm (DiffusionGemmaRMSNorm) [weight (256,)]                                                               256
#             v_norm (DiffusionGemmaRMSNorm)                                                                                 0
#           mlp (DiffusionGemmaText4MLP)                                                                                17.84M
#             gate_proj (Linear) [in_features=2816, out_features=2112, bias=False]                                       5.95M
#             up_proj (Linear) [in_features=2816, out_features=2112, bias=False]                                         5.95M
#             down_proj (Linear) [in_features=2112, out_features=2816, bias=False]                                       5.95M
#             act_fn (GELUTanh)                                                                                              0
#           input_layernorm (DiffusionGemmaRMSNorm) [weight (2816,)]                                                     2.82K
#           post_attention_layernorm (DiffusionGemmaRMSNorm) [weight (2816,)]                                            2.82K
#           pre_feedforward_layernorm (DiffusionGemmaRMSNorm) [weight (2816,)]                                           2.82K
#           post_feedforward_layernorm (DiffusionGemmaRMSNorm) [weight (2816,)]                                          2.82K
#           router (DiffusionGemmaTextRouter) [scale (2816,), per_expert_scale (128,)]                                 363.39K
#             norm (DiffusionGemmaRMSNorm)                                                                                   0
#             proj (Linear) [in_features=2816, out_features=128, bias=False]                                           360.45K
#           experts (DiffusionGemmaTextExperts) [gate_up_proj (128, 1408, 2816), down_proj (128, 2816, 704)]           761.27M
#             act_fn (GELUTanh)                                                                                              0
#           post_feedforward_layernorm_1 (DiffusionGemmaRMSNorm) [weight (2816,)]                                        2.82K
#           post_feedforward_layernorm_2 (DiffusionGemmaRMSNorm) [weight (2816,)]                                        2.82K
#           pre_feedforward_layernorm_2 (DiffusionGemmaRMSNorm) [weight (2816,)]                                         2.82K
#       norm (DiffusionGemmaRMSNorm) [weight (2816,)]                                                                    2.82K
#       rotary_emb (DiffusionGemmaTextRotaryEmbedding)                                                                       0
#       self_conditioning (DiffusionGemmaSelfConditioning)                                                              17.84M
#         pre_norm (DiffusionGemmaRMSNorm) [weight (2816,)]                                                              2.82K
#         post_norm (DiffusionGemmaRMSNorm)                                                                                  0
#         gate_proj (Linear) [in_features=2816, out_features=2112, bias=False]                                           5.95M
#         up_proj (Linear) [in_features=2816, out_features=2112, bias=False]                                             5.95M
#         down_proj (Linear) [in_features=2112, out_features=2816, bias=False]                                           5.95M
#         act_fn (GELUTanh)                                                                                                  0
#   lm_head (Linear) [in_features=2816, out_features=262144, bias=False]                                               738.20M
# ============================================================================================================================
# Total params                                                                                                          25.82B
# Total params (raw)                                                                                            25,823,778,864
# ============================================================================================================================
